# %% [markdown]
# 쿠키 - 홈페이지에서 내가 변화를 준 정보를 가진 데이터 조각
#
# HTTP는 비 연결 지향 & 무상태이므로 쿠키를 사용해서 사용자가 변화한 데이터르 다 저장해서 이를 계속 요청받아와야 함
#
# - 쿠키 사용 목적
#
# - 세션관리 - 로그인(수업때 배울 내용)
#   - 서버 측에서 생성되어 있는
# - User name
# - 아이디가 이메일 등 다양한 형태일 수 있음
# - user모델을 수정해야 되는데 내장것을 직접 수정할 수 없으므로 user클래스를 대체해야 됨
#   - 3단계가 있음
#     - 1단계 유저클래스를 직접 만들어야 됨 이것은 내장함수로 편하게 구현가능
#     - 2단계 이것을 쓰라고 settings.py에 등록해야 됨 앱이름.User auth는 내장 유저 클래스
#
# 이름 충돌 방지 해줘야 됨
