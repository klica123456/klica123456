# %% [markdown]
# - 신장 트리란?
# 1. 모든 정점을 연결
# 2. 사이클이 존재하지 않는 부분 그래프
#         - 간선의 개수 : N-1개
# 3. 한 그래프에서 여러개의 신장 트리가 나올 수 있다. - 주의하면서 문제 풀어야 됨
#
# 우리는 도로 건설 계획을 세우고 있다.
# 총 N개의 조시를 연결하는 도로를 건설하려고 할 때
# 모든 도시에 갈 수 있도록하며, 가장 비용이 적게 들도록
# 도로를 건설하는 경우의 수를 구하시오.
#
# grid알고리즘
# 갈 수 있는 곳들 중 제일 짧은 곳으로 가자.
# - 모든 정점을 방문할 때까지
#
# 전체 간선들 중에서 제일 가중치가 적은 곳부터 선택하자
#
# sort안에서 lamda쓰는 법 연습

# %% [markdown]
# 최단 거리 문제 유형
# - 1. 특정 지점 -> 도착 지점까지의 최단 거리 : 다익스트라
# - 2. 가중치에 음수가 포함되어 있네? : 밸만초드
# - 3. 여러 지점 -> 여러 지점까지의 최단 거리
#         - 여러 지점 모두 다익스트라 돌리기 -> 시간 복잡도 계산 잘해야 함
#         - 플로이드 -워샬
#
#   그래프
#
#   그래프 탐색
#   - 완전 탐색 : DFS, BFS
#
#   서로소 집합
#   - 대표 데이터 비교
#   - 그래프 에서는 싸이클 판별
#
#   최소 비용
#   1. 최소신장트리(MST)
#       - 전체 그래프에서 총합이 최소인 신장 트리
#   2. 최단 거리(다익 스트라)
#       - 정점 사이의 거리가 최단인 경로 찾기
